# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('gender.csv')

# %%
data.head()
# Out:
#    meanfreq        sd    median       Q25       Q75       IQR       skew  \
# 0  0.059781  0.064241  0.032027  0.015071  0.090193  0.075122  12.863462
# 1  0.066009  0.067310  0.040229  0.019414  0.092666  0.073252  22.423285
# 2  0.077316  0.083829  0.036718  0.008701  0.131908  0.123207  30.757155
# 3  0.151228  0.072111  0.158011  0.096582  0.207955  0.111374   1.232831
# 4  0.135120  0.079146  0.124656  0.078720  0.206045  0.127325   1.101174
#
#           kurt    sp.ent       sfm  ...    centroid   meanfun    minfun  \
# 0   274.402906  0.893369  0.491918  ...    0.059781  0.084279  0.015702
# 1   634.613855  0.892193  0.513724  ...    0.066009  0.107937  0.015826
# 2  1024.927705  0.846389  0.478905  ...    0.077316  0.098706  0.015656
# 3     4.177296  0.963322  0.727232  ...    0.151228  0.088965  0.017798
# 4     4.333713  0.971955  0.783568  ...    0.135120  0.106398  0.016931
#
#      maxfun   meandom    mindom    maxdom   dfrange   modindx  label
# ...

# %%
df=data

# %%
y=df.iloc[:,-1]

# %%
y.head()
# Out:
# 0    male
# 1    male
# 2    male
# 3    male
# 4    male
# Name: label, dtype: object

# %%
x=df.iloc[:, :-1]
x.head()
# Out:
#    meanfreq        sd    median       Q25       Q75       IQR       skew  \
# 0  0.059781  0.064241  0.032027  0.015071  0.090193  0.075122  12.863462
# 1  0.066009  0.067310  0.040229  0.019414  0.092666  0.073252  22.423285
# 2  0.077316  0.083829  0.036718  0.008701  0.131908  0.123207  30.757155
# 3  0.151228  0.072111  0.158011  0.096582  0.207955  0.111374   1.232831
# 4  0.135120  0.079146  0.124656  0.078720  0.206045  0.127325   1.101174
#
#           kurt    sp.ent       sfm      mode  centroid   meanfun    minfun  \
# 0   274.402906  0.893369  0.491918  0.000000  0.059781  0.084279  0.015702
# 1   634.613855  0.892193  0.513724  0.000000  0.066009  0.107937  0.015826
# 2  1024.927705  0.846389  0.478905  0.000000  0.077316  0.098706  0.015656
# 3     4.177296  0.963322  0.727232  0.083878  0.151228  0.088965  0.017798
# 4     4.333713  0.971955  0.783568  0.104261  0.135120  0.106398  0.016931
#
#      maxfun   meandom    mindom    maxdom   dfrange   modindx
# ...

# %%
from sklearn.preprocessing import LabelEncoder
gender_encoder = LabelEncoder()
y= gender_encoder.fit_transform(y)
y
# Out:
# array([1, 1, 1, ..., 0, 0, 0], dtype=int64)

# %% [markdown]
# Before Scaling Process
# -----------------------

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test =train_test_split(x, y, test_size=0.2, random_state=1)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics

knn = KNeighborsClassifier()
knn.fit(x_train,y_train)
y_pred=knn.predict(x_test)
print('Accuracy')
print(metrics.accuracy_score(y_test,y_pred))
# Out:
# Accuracy
# 0.722397476341

# %%
p=[]
for k in range(1, 100):
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(x_train,y_train)
    y_pred=knn.predict(x_test)
    acc = metrics.accuracy_score(y_test,y_pred)
    p.append(acc)
    print("accuracy when k=",k,"----",acc)
    
max_value = max(p)
index_value = p.index(max(p)) + 1
print("accuracy is high at ",index_value,"====",max_value)
# Out:
# accuracy when k= 1 ---- 0.708201892744
# accuracy when k= 2 ---- 0.712933753943
# accuracy when k= 3 ---- 0.717665615142
# accuracy when k= 4 ---- 0.723974763407
# accuracy when k= 5 ---- 0.722397476341
# accuracy when k= 6 ---- 0.695583596215
# accuracy when k= 7 ---- 0.708201892744
# accuracy when k= 8 ---- 0.692429022082
# accuracy when k= 9 ---- 0.708201892744
# accuracy when k= 10 ---- 0.700315457413
# accuracy when k= 11 ---- 0.711356466877
# accuracy when k= 12 ---- 0.708201892744
# accuracy when k= 13 ---- 0.711356466877
# accuracy when k= 14 ---- 0.703470031546
# accuracy when k= 15 ---- 0.719242902208
# accuracy when k= 16 ---- 0.705047318612
# accuracy when k= 17 ---- 0.714511041009
# accuracy when k= 18 ---- 0.698738170347
# accuracy when k= 19 ---- 0.706624605678
# accuracy when k= 20 ---- 0.701892744479
# accuracy when k= 21 ---- 0.712933753943
# accuracy when k= 22 ---- 0.708201892744
# accuracy when k= 23 ---- 0.703470031546
# accuracy when k= 24 ---- 0.694006309148
# ...

# %% [markdown]
# The accuracy is low before scaling and maximum at k = 4.

# %% [markdown]
# After Scaling Process
# ----------------------

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(x)
x = scaler.transform(x)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test =train_test_split(x, y, test_size=0.2, random_state=1)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics

knn = KNeighborsClassifier()
knn.fit(x_train,y_train)
y_pred=knn.predict(x_test)
print('Accuracy')
print(metrics.accuracy_score(y_test,y_pred))
# Out:
# Accuracy
# 0.965299684543

# %%
p=[]
for k in range(1, 100):
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(x_train,y_train)
    y_pred=knn.predict(x_test)
    acc = metrics.accuracy_score(y_test,y_pred)
    p.append(acc)
    print("accuracy when k=",k,"----",acc)
    
max_value = max(p)
index_value = p.index(max(p)) + 1
print("accuracy is high at ",index_value,"====",max_value)
# Out:
# accuracy when k= 1 ---- 0.971608832808
# accuracy when k= 2 ---- 0.968454258675
# accuracy when k= 3 ---- 0.971608832808
# accuracy when k= 4 ---- 0.965299684543
# accuracy when k= 5 ---- 0.965299684543
# accuracy when k= 6 ---- 0.966876971609
# accuracy when k= 7 ---- 0.970031545741
# accuracy when k= 8 ---- 0.968454258675
# accuracy when k= 9 ---- 0.965299684543
# accuracy when k= 10 ---- 0.966876971609
# accuracy when k= 11 ---- 0.965299684543
# accuracy when k= 12 ---- 0.965299684543
# accuracy when k= 13 ---- 0.965299684543
# accuracy when k= 14 ---- 0.963722397476
# accuracy when k= 15 ---- 0.963722397476
# accuracy when k= 16 ---- 0.963722397476
# accuracy when k= 17 ---- 0.96214511041
# accuracy when k= 18 ---- 0.96214511041
# accuracy when k= 19 ---- 0.96214511041
# accuracy when k= 20 ---- 0.96214511041
# accuracy when k= 21 ---- 0.96214511041
# accuracy when k= 22 ---- 0.963722397476
# accuracy when k= 23 ---- 0.960567823344
# accuracy when k= 24 ---- 0.960567823344
# ...

# %% [markdown]
# When we Scale the varibale and set the mean to zero and standard deviation to be one, then there is an increase in accuracy and the highest k value accuracy is at 1.
